# %%
##Write logic to ask the user for their age and determine if they are eligible to vote based on whether they are 18 or older.##

# %%
age=int(input("Enter your age"))
if(age>=18):
    print("Eligible to vote")
else:
    print("Not Eligible to vote")
# Out:
# Enter your age 20
# Eligible to vote

# %%
##Write logic to identify and return the largest number from a given list.##

# %%
lists=[20,90,94,38,84.56,76,98,101]
lar_num=max(lists)
print("Largest number is:", lar_num)
# Out:
# Largest number is: 101

# %%
##Write logic to determine the bonus amount based on the given salary.##

# %%
Salary=int(input("Enter the salary:"))
if(Salary>=50000):
    print("Salary incremented by 10%:",Salary+Salary*10/100)
else:
    print(Salary)
# Out:
# Enter the salary: 60000
# Salary incremented by 10%: 66000.0

# %%
Salary=int(input("Enter the salary:"))
if(Salary>=50000):
    print("Salary incremented by 10%:",Salary+Salary*10/100)
else:
    print(Salary)
# Out:
# Enter the salary: 30000
# 30000

# %%
## Write logic to check whether a given number is even or odd.##

# %%
num=int(input("Enter the number:"))
if(num%2==0):
    print("It is Even number")
else:
    print("It is Odd number")
# Out:
# Enter the number: 900
# It is Even number

# %%
##Write logic to take a word or sentence as input and produce its reversed version.##

# %%
## Write logic to check if a student has passed a subject by scoring at least 40 marks.##

# %%
mark=int(input("Enter the mark:"))
if(mark>=40):
    print("Pass")
else:
    print("Fail")
# Out:
# Enter the mark: 42
# Pass

# %%
##Write logic to calculate the final amount to be paid after applying the discount##

# %%
Totalpayment=int(input("Enter total amount:"))
if(Totalpayment>=100):
    print("Payment after discount:", Totalpayment-Totalpayment*20/100)
else:
    print("No Discount", Totalpayment)
# Out:
# Enter total amount: 200
# Payment after discount: 160.0

# %%
Totalpayment=int(input("Enter total amount:"))
if(Totalpayment>=100):
    print("Payment after discount:", Totalpayment-Totalpayment*20/100)
else:
    print("No Discount", Totalpayment)
# Out:
# Enter total amount: 98
# No Discount 98

# %%
## Write logic to check if a user has enough balance before allowing a withdrawal and update the remaining balance accordingly.
##

# %%
Acc_Balance=500
withdraw_amt=int(input("Enter the withdrawal amount:"))
if(withdraw_amt>=500):
    print("Your current bank balane is crossing the minimum balance limit and Your current bank balance is:",Acc_Balance)
else:
    print("Your current bank balane is:",Acc_Balance-withdraw_amt)
# Out:
# Enter the withdrawal amount: 600
# Your current bank balane is crossing the minimum balance limit and Your current bank balance is: 500

# %%
Acc_Balance=500
withdraw_amt=int(input("Enter the withdrawal amount:"))
if(withdraw_amt>=500):
    print("Your current bank balane is crossing the minimum balance limit and Your current bank balance is:",Acc_Balance)
else:
    print("Your current bank balane is:",Acc_Balance-withdraw_amt)
# Out:
# Enter the withdrawal amount: 400
# Your current bank balane is: 100

# %%
##logic to determine whether a given year is a leap year##

# %%
Year=int(input("Enter the year:"))
if(Year%4==0):
    print("Leap year")
else:
    print("Its not a leap year")
# Out:
# Enter the year: 2012
# Leap year

# %%
Year=int(input("Enter the year:"))
if(Year%4==0):
    print("Leap year")
else:
    print("Its not a leap year")
# Out:
# Enter the year: 2011
# Its not a leap year

# %%
##Write logic to extract and return only the even numbers from a list.##

# %%
lists1=[34,67,81,92,66,45,21,99,100,38,46]

# %%
for temp in lists1:
    if(temp%2==0):
        print(temp,"is Even number")
# Out:
# 34 is Even number
# 92 is Even number
# 66 is Even number
# 100 is Even number
# 38 is Even number
# 46 is Even number
