# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

# %%
a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# %%
def add_numbers(a,b):
    return a+b
add_numbers(2,1)
# Out:
# 3

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

# %%
numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
##throw error as numbers will not be divided by 0 ##
X = 5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[71], line 3
#       1 #6.Find the error in the following Python code:
#       2 ##throw error as numbers will not be divided by 0 ##
# ----> 3 X = 5/0
#
# ZeroDivisionError: division by zero

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
name=input("Name:")
print("Name:",name + " Age:",age)
# Out:
# Name: Alice
# Name: Alice Age: 25

# %%
#8.Find the error
for i in range(10, 1,-1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#9. Find the error in the following Python code:
x = 10
if(x==5):
    print("x is 5")
else:
    print("X is",x)
# Out:
# X is 10

# %%
#10. Identify the error in the following function definition:

def greet(name):
    print("Hello,"+name)

# %%
greet('HOPE')
# Out:
# Hello,HOPE
